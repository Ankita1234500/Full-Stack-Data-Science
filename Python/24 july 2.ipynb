# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mhetr'

# %%
movies = pd.read_csv(r"C:\Users\mhetr\Downloads\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMulillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMulillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    object
#  1   Genre             559 non-null    object
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetMulillions  559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMulillions         Year
# count    559.000000      559.000000        559.000000   559.000000
# mean      47.309481       58.744186         50.236136  2009.152057
# std       26.413091       16.826887         48.731817     1.362632
# min        0.000000        0.000000          0.000000  2007.000000
# 25%       25.000000       47.000000         20.000000  2008.000000
# 50%       46.000000       58.000000         35.000000  2009.000000
# 75%       70.000000       72.000000         65.000000  2010.000000
# max       97.000000       96.000000        300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMulillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    object
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetMulillions  559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    category
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetMulillions  559 non-null    int64
#  5   Year              559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMulillions
# count    559.000000      559.000000        559.000000
# mean      47.309481       58.744186         50.236136
# std       26.413091       16.826887         48.731817
# min        0.000000        0.000000          0.000000
# 25%       25.000000       47.000000         20.000000
# 50%       46.000000       58.000000         35.000000
# 75%       70.000000       72.000000         65.000000
# max       97.000000       96.000000        300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')
plt.show()

# %%
m1 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2c= sns.distplot(movies.AudienceRating,bins=15)
plt.show()

# %%
n1 = plt.hist(movies.AudienceRating, bins=15)
plt.show()

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRating,bins=20)
plt.show()

# %%
n1=plt.hist(movies.CriticRating, bins=20)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMulillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009

# %%
print (movies.columns)
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMulillions',
#        'Year'],
#       dtype='object')

# %%
plt.hist(movies.BudgetMulillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMulillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMulillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMulillions, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMulillions, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMulillions, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMulillions,\
          movies[movies.Genre == 'Drama'].BudgetMulillions, \
          movies[movies.Genre == 'Thriller'].BudgetMulillions, \
          movies[movies.Genre == 'Comedy'].BudgetMulillions],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre')
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre', aspect=1) 
plt.show(vis1)

# %%
k1 = sns.kdeplot(x=movies["CriticRating"], y=movies["AudienceRating"])
plt.show()

# %%
k1 = sns.kdeplot(
    x=movies["CriticRating"],
    y=movies["AudienceRating"],
    fill=True,               # replaces deprecated `shade=True`
    cmap='Reds',             # color map
    thresh=0.05              # minimum contour level to show
)
plt.title("2D KDE Plot: Critic vs Audience Rating")
plt.show()

# %%
k2 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade_lowest=False,cmap='Greens_r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 k2 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade_lowest=False,cmap='Greens_r')
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
k2 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, cmap='Greens_r', fill=True)
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.BudgetMulillions,movies.AudienceRating,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.AudienceRating, cmap='Greens_r', fill=True)
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.BudgetMulillions,movies.AudienceRating)

# %%
sns.scatterplot(x=movies.BudgetMulillions, y=movies.AudienceRating)
sns.kdeplot(x=movies.BudgetMulillions, y=movies.AudienceRating, fill=True, cmap='Greens', alpha=0.5)
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.AudienceRating, fill=True)
plt.show()

# %%
k2 = sns.kdeplot(movies.BudgetMulillions,movies.CriticRating)
plt.show()

# %%
k2 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.CriticRating, fill=True, cmap='Greens')
plt.show()

# %%
f, ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(movies.BudgetMulillions,movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMulillions,movies.CriticRating,ax = axes[1])
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(12, 6))

k1 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.AudienceRating, ax=axes[0], fill=True, cmap='Greens')
k2 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.CriticRating, ax=axes[1], fill=True, cmap='Reds')

plt.tight_layout()
plt.show()

# %%
axes

# %%
w = sns.boxplot(data = movies,x='Genre',y='CriticRating')
plt.show()

# %%
z=sns.violinplot(data=movies, x='Genre',y='CriticRating')
plt.show()

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
z=sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
plt.show()

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' )
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMulillions')
plt.show()

# %%
 g=sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movies.BudgetMulillions,movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMulillions,movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15, 15))

k1 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.AudienceRating, ax=axes[0, 0], fill=True, cmap='Greens')
k2 = sns.kdeplot(x=movies.BudgetMulillions, y=movies.CriticRating, ax=axes[0, 1], fill=True, cmap='Reds')

k1.set(xlim=(-20, 160))

plt.tight_layout()
plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(movies.BudgetMulillions,movies.AudienceRating, \
                 shade = True, shade_lowest=True,cmp = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(movies.BudgetMulillions, movies.AudienceRating, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(movies.BudgetMulillions,movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(movies.BudgetMulillions,movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %%
k1 = sns.kdeplot(
    x=movies.BudgetMulillions,
    y=movies.AudienceRating,
    fill=True,
    cmap='inferno',
    ax=axes[0, 0]
)

k1b = sns.kdeplot(
    x=movies.BudgetMulillions,
    y=movies.AudienceRating,
    cmap='cool',
    ax=axes[0, 0]
)
plt.show()

# %%
k1 = sns.kdeplot(
    x=movies.BudgetMulillions,
    y=movies.AudienceRating,
    shade=True,
    cmap='inferno',
    ax=axes[0, 0]
)

k1b = sns.kdeplot(
    x=movies.BudgetMulillions,
    y=movies.AudienceRating,
    cmap='cool',
    ax=axes[0, 0]
)
plt.show()
